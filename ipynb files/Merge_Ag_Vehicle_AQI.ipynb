# %% [markdown]
# # Merging Agricultural and Vehicle Data to AQI Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
#read all datasets for merging
vehicle = pd.read_csv('cleaned_vehicle_registration.csv')
demo = pd.read_csv('combined demographic.csv')
crops = pd.read_csv('Cropland by municipality_cleaned.csv')
pigs = pd.read_csv('Pigs by municipality_cleaned.csv')
cattle = pd.read_csv('Cattle and calves by municipality_cleaned.csv')

# %%
#Read data to ensure same dtype and columns names
vehicle.dtypes
# Out:
# Municipality          object
# Year                   int64
# Vehicle_Type          object
# Registration_Count     int64
# dtype: object

# %%
comb_demo.head()
# Out:
#   Unique CSD  Unique Year  Combined Key  Adjusted Air Quality Health Index  \
# 0   Red Deer         2011  Red Deer2011                            2.74906
# 1   Red Deer         2012  Red Deer2012                            2.43250
# 2   Red Deer         2013  Red Deer2013                            2.54466
# 3   Red Deer         2014  Red Deer2014                            2.23417
# 4   Red Deer         2015  Red Deer2015                            2.26231
#
#    Both Sexes Life Expectancy (Years)  Population
# 0                               79.96       75553
# 1                               80.00       77674
# 2                               80.17       79180
# 3                               80.20       80290
# 4                               80.37       80049

# %%
crops = crops.drop(columns=['CSDUID','IndicatorSummaryDescription'])

# %%
pigs = pigs.drop(columns=['CSDUID','IndicatorSummaryDescription'])

# %%
cattle = cattle.drop(columns=['CSDUID', 'IndicatorSummaryDescription'])

# %%
pigs.dtypes
# Out:
# CSD        object
# Period      int64
# Count     float64
# dtype: object

# %%
cattle.head()
# Out:
#                CSD  Period    Count
# 0  Starland County    2001      0.0
# 1  Starland County    2006  34341.0
# 2  Starland County    2011  35178.0
# 3  Starland County    2016  54027.0
# 4  Starland County    2021  33028.0

# %%
crops.tail()
# Out:
#                           CSD  Period Crop Type     Count
# 1701  Two Hills County No. 21    2021     Other   62591.0
# 1702        Yellowhead County    2006     Other  108480.0
# 1703        Yellowhead County    2011     Other   95569.0
# 1704        Yellowhead County    2016     Other   84238.0
# 1705        Yellowhead County    2021     Other   80023.0

# %%
veh_column_map = {'Municipality':'CSD','Year':'Period','Vehicle_Type':'Vehicle_Type','Registration_Count':'Vehicle_Registrations'}

# %%
vehicle.rename(columns=veh_column_map, inplace=True)
vehicle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CSD                    480 non-null    object
#  1   Period                 480 non-null    int64
#  2   Vehicle_Type           480 non-null    object
#  3   Vehicle_Registrations  480 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 15.1+ KB

# %%
demo = demo.drop(columns=['Combined Key'])
demo.head()
# Out:
#   Unique CSD  Unique Year  Adjusted Air Quality Health Index  \
# 0   Red Deer         2011                            2.74906
# 1   Red Deer         2012                            2.43250
# 2   Red Deer         2013                            2.54466
# 3   Red Deer         2014                            2.23417
# 4   Red Deer         2015                            2.26231
#
#    Both Sexes Life Expectancy (Years)  Population
# 0                               79.96       75553
# 1                               80.00       77674
# 2                               80.17       79180
# 3                               80.20       80290
# 4                               80.37       80049

# %%
demo_column_map = {'Unique CSD': 'CSD', 'Unique Year': 'Period'}

# %%
demo.rename(columns=demo_column_map, inplace=True)
demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   CSD                                 284 non-null    object
#  1   Period                              284 non-null    int64
#  2   Adjusted Air Quality Health Index   284 non-null    float64
#  3   Both Sexes Life Expectancy (Years)  267 non-null    float64
#  4   Population                          284 non-null    int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 11.2+ KB

# %%
crops.rename(columns={'Crop Type':'Crop_Type','Count': 'Crop_Count'}, inplace=True)
crops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1706 entries, 0 to 1705
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSD         1706 non-null   object
#  1   Period      1706 non-null   int64
#  2   Crop_Type   1706 non-null   object
#  3   Crop_Count  1706 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 53.4+ KB

# %%
pigs.rename(columns={'Count': 'Pig_Count'}, inplace=True)
pigs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354 entries, 0 to 353
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CSD        354 non-null    object
#  1   Period     354 non-null    int64
#  2   Pig_Count  354 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 8.4+ KB

# %%
cattle.rename(columns={'Count': 'Cattle_and_Calves_Count'}, inplace=True)
cattle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352 entries, 0 to 351
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CSD                      352 non-null    object
#  1   Period                   352 non-null    int64
#  2   Cattle_and_Calves_Count  352 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 8.4+ KB

# %%
# merge time
merge1 = pd.merge(demo, vehicle, on=['CSD', 'Period'], how='outer')
merge2 = pd.merge(merge1, crops, on=['CSD', 'Period'], how='outer')
merge3 = pd.merge(merge2, pigs, on=['CSD', 'Period'], how='outer')
merge4 = pd.merge(merge3, cattle, on=['CSD', 'Period'], how='outer')
merge4
# Out:
#                     CSD  Period  Adjusted Air Quality Health Index  \
# 0               Airdrie    2005                                NaN
# 1               Airdrie    2006                                NaN
# 2               Airdrie    2007                                NaN
# 3               Airdrie    2008                                NaN
# 4               Airdrie    2009                                NaN
# ...                 ...     ...                                ...
# 2252  Yellowhead County    2021                            2.11912
# 2253  Yellowhead County    2021                            2.11912
# 2254  Yellowhead County    2021                            2.11912
# 2255  Yellowhead County    2021                            2.11912
# 2256  Yellowhead County    2022                            2.10516
#
#       Both Sexes Life Expectancy (Years)  Population  \
# 0                                    NaN         NaN
# 1                                    NaN         NaN
# 2                                    NaN         NaN
# 3                                    NaN         NaN
# 4                                    NaN         NaN
# ...                                  ...         ...
# 2252                               79.25      6835.0
# 2253                               79.25      6835.0
# 2254                               79.25      6835.0
# 2255                               79.25      6835.0
# 2256                               79.07      6824.0
#
#                   Vehicle_Type  Vehicle_Registrations        Crop_Type  \
# 0     Total Motorized Vehicles                24609.0              NaN
# 1     Total Motorized Vehicles                27288.0              NaN
# 2     Total Motorized Vehicles                30095.0              NaN
# 3     Total Motorized Vehicles                32293.0              NaN
# 4     Total Motorized Vehicles                36368.0              NaN
# ...                        ...                    ...              ...
# 2252                       NaN                    NaN      Durum Wheat
# 2253                       NaN                    NaN  Non-durum Wheat
# 2254                       NaN                    NaN             Oats
# 2255                       NaN                    NaN            Other
# 2256                       NaN                    NaN              NaN
#
#       Crop_Count  Pig_Count  Cattle_and_Calves_Count
# 0            NaN        NaN                      NaN
# 1            NaN        NaN                      NaN
# 2            NaN        NaN                      NaN
# 3            NaN        NaN                      NaN
# 4            NaN        NaN                      NaN
# ...          ...        ...                      ...
# 2252         0.0        0.0                  60209.0
# 2253         0.0        0.0                  60209.0
# 2254     15741.0        0.0                  60209.0
# 2255     80023.0        0.0                  60209.0
# 2256         NaN        NaN                      NaN
#
# [2257 rows x 11 columns]

# %%
merge4.dtypes
# Out:
# CSD                                    object
# Period                                  int64
# Adjusted Air Quality Health Index     float64
# Both Sexes Life Expectancy (Years)    float64
# Population                            float64
# Vehicle_Type                           object
# Vehicle_Registrations                 float64
# Crop_Type                              object
# Crop_Count                            float64
# Pig_Count                             float64
# Cattle_and_Calves_Count               float64
# dtype: object

# %%
merge4[190:210]
# Out:
#                    CSD  Period  Adjusted Air Quality Health Index  \
# 190  Bonnyville No. 87    2006                                NaN
# 191  Bonnyville No. 87    2006                                NaN
# 192  Bonnyville No. 87    2006                                NaN
# 193  Bonnyville No. 87    2006                                NaN
# 194  Bonnyville No. 87    2007                                NaN
# 195  Bonnyville No. 87    2008                                NaN
# 196  Bonnyville No. 87    2009                                NaN
# 197  Bonnyville No. 87    2010                                NaN
# 198  Bonnyville No. 87    2011                                NaN
# 199  Bonnyville No. 87    2011                                NaN
# 200  Bonnyville No. 87    2011                                NaN
# 201  Bonnyville No. 87    2011                                NaN
# 202  Bonnyville No. 87    2011                                NaN
# 203  Bonnyville No. 87    2011                                NaN
# 204  Bonnyville No. 87    2012                                NaN
# 205  Bonnyville No. 87    2013                                NaN
# 206  Bonnyville No. 87    2014                                NaN
# 207  Bonnyville No. 87    2015                                NaN
# 208  Bonnyville No. 87    2016                             1.7422
# 209  Bonnyville No. 87    2016                             1.7422
#
#      Both Sexes Life Expectancy (Years)  Population              Vehicle_Type  \
# 190                                 NaN         NaN  Total Motorized Vehicles
# 191                                 NaN         NaN  Total Motorized Vehicles
# 192                                 NaN         NaN  Total Motorized Vehicles
# 193                                 NaN         NaN  Total Motorized Vehicles
# 194                                 NaN         NaN  Total Motorized Vehicles
# 195                                 NaN         NaN  Total Motorized Vehicles
# 196                                 NaN         NaN  Total Motorized Vehicles
# 197                                 NaN         NaN  Total Motorized Vehicles
# 198                                 NaN         NaN  Total Motorized Vehicles
# 199                                 NaN         NaN  Total Motorized Vehicles
# 200                                 NaN         NaN  Total Motorized Vehicles
# 201                                 NaN         NaN  Total Motorized Vehicles
# 202                                 NaN         NaN  Total Motorized Vehicles
# 203                                 NaN         NaN  Total Motorized Vehicles
# 204                                 NaN         NaN  Total Motorized Vehicles
# 205                                 NaN         NaN  Total Motorized Vehicles
# 206                                 NaN         NaN  Total Motorized Vehicles
# 207                                 NaN         NaN  Total Motorized Vehicles
# 208                               79.11      9693.0  Total Motorized Vehicles
# 209                               79.11      9693.0  Total Motorized Vehicles
#
#      Vehicle_Registrations        Crop_Type  Crop_Count  Pig_Count  \
# 190                 2513.0      Durum Wheat         0.0     1162.0
# 191                 2513.0  Non-durum Wheat      8921.0     1162.0
# 192                 2513.0             Oats     25376.0     1162.0
# 193                 2513.0            Other    156417.0     1162.0
# 194                 2696.0              NaN         NaN        NaN
# 195                 2830.0              NaN         NaN        NaN
# 196                 3010.0              NaN         NaN        NaN
# 197                 3010.0              NaN         NaN        NaN
# 198                 3168.0           Barley     26761.0      113.0
# 199                 3168.0           Canola     42233.0      113.0
# 200                 3168.0      Durum Wheat         0.0      113.0
# 201                 3168.0  Non-durum Wheat         0.0      113.0
# 202                 3168.0             Oats     17842.0      113.0
# 203                 3168.0            Other    164132.0      113.0
# 204                 3316.0              NaN         NaN        NaN
# 205                 3572.0              NaN         NaN        NaN
# 206                 3723.0              NaN         NaN        NaN
# 207                 3592.0              NaN         NaN        NaN
# 208                 3474.0           Barley     23576.0      289.0
# 209                 3474.0           Canola     37579.0      289.0
#
#      Cattle_and_Calves_Count
# 190                  94119.0
# 191                  94119.0
# 192                  94119.0
# 193                  94119.0
# 194                      NaN
# 195                      NaN
# 196                      NaN
# 197                      NaN
# 198                  63418.0
# 199                  63418.0
# 200                  63418.0
# 201                  63418.0
# 202                  63418.0
# 203                  63418.0
# 204                      NaN
# 205                      NaN
# 206                      NaN
# 207                      NaN
# 208                  60842.0
# 209                  60842.0

# %%
# Out:
#                    CSD  Period  Adjusted Air Quality Health Index  \
# 130  Strathcona County    2015                            2.30421
# 131  Strathcona County    2016                            2.13355
# 132  Strathcona County    2017                            2.38307
# 133  Strathcona County    2018                            2.57518
# 134  Strathcona County    2019                            2.34714
# 135  Strathcona County    2020                            2.26426
# 136  Strathcona County    2021                            2.35545
# 137  Strathcona County    2022                            2.33306
# 138    Sturgeon County    2016                            1.94946
# 139    Sturgeon County    2017                            2.26669
#
#      Both Sexes Life Expectancy (Years)  Population
# 130                               81.93       74131
# 131                               82.08       74185
# 132                               82.16       73842
# 133                               82.24       73301
# 134                               82.42       72911
# 135                               82.38       72206
# 136                               82.28       71127
# 137                               82.17       71041
# 138                               79.17       15819
# 139                               79.33       15616
