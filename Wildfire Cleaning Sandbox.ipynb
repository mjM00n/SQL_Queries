# %% [markdown]
# # WildFire Cleaning

# %%
#!pip install opencage
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from opencage.geocoder import OpenCageGeocode
from pprint import pprint

# https://opencagedata.com/pricing
# https://opencagedata.com/api#quickstart
# https://opencagedata.com/api

# %%
wildfiredf = pd.read_excel("historical-wildfire-data-2006-2023.xlsx")

# %%
wildfiredf.head()
# Out:
#    fire_year fire_number fire_name  current_size size_class  \
# 0       2006      PWF001       NaN          0.10          A
# 1       2006      EWF002       NaN          0.20          B
# 2       2006      EWF001       NaN          0.50          B
# 3       2006      EWF003       NaN          0.01          A
# 4       2006      PWF002       NaN          0.10          A
#
#    fire_location_latitude  fire_location_longitude      fire_origin  \
# 0               56.249956              -117.181960     Private Land
# 1               53.606367              -115.915733  Provincial Land
# 2               53.610933              -115.594267  Provincial Land
# 3               53.608867              -115.609467  Provincial Land
# 4               56.249956              -117.050249  Provincial Land
#
#   general_cause_desc industry_identifier_desc  ... distance_from_water_source  \
# 0           Resident                      NaN  ...                        NaN
# ...

# %%
wildfiredf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25321 entries, 0 to 25320
# Data columns (total 50 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   fire_year                     25321 non-null  int64
#  1   fire_number                   25321 non-null  object
#  2   fire_name                     729 non-null    object
#  3   current_size                  25321 non-null  float64
#  4   size_class                    25321 non-null  object
#  5   fire_location_latitude        25321 non-null  float64
#  6   fire_location_longitude       25321 non-null  float64
#  7   fire_origin                   25305 non-null  object
#  8   general_cause_desc            25321 non-null  object
#  9   industry_identifier_desc      462 non-null    object
#  10  responsible_group_desc        9383 non-null   object
#  11  activity_class                15548 non-null  object
# ...

# %%
wildfiredf.head()
# Out:
#    fire_year fire_number fire_name  current_size size_class  \
# 0       2006      PWF001       NaN          0.10          A
# 1       2006      EWF002       NaN          0.20          B
# 2       2006      EWF001       NaN          0.50          B
# 3       2006      EWF003       NaN          0.01          A
# 4       2006      PWF002       NaN          0.10          A
#
#    fire_location_latitude  fire_location_longitude      fire_origin  \
# 0               56.249956              -117.181960     Private Land
# 1               53.606367              -115.915733  Provincial Land
# 2               53.610933              -115.594267  Provincial Land
# 3               53.608867              -115.609467  Provincial Land
# 4               56.249956              -117.050249  Provincial Land
#
#   general_cause_desc industry_identifier_desc  ... distance_from_water_source  \
# 0           Resident                      NaN  ...                        NaN
# ...

# %%
wildfiredf = wildfiredf.drop(columns = ['fire_origin', 
                                      'general_cause_desc', 
                                      'industry_identifier_desc', 
                                     'responsible_group_desc',
                                     'activity_class', 
                                     'true_cause',
                                     'det_agent_type',
                                     'det_agent',
                                     'discovered_size',
                                     'dispatched_resource',
                                     'assessment_resource',
                                     'assessment_hectares',
                                     'fire_spread_rate',
                                     'fire_type',
                                     'fire_position_on_slope',
                                     'weather_conditions_over_fire',
                                     'temperature',
                                     'relative_humidity',
                                     'fuel_type',
                                     'initial_action_by',
                                     'ia_access',
                                     'fire_fighting_start_size',
                                     'bucketing_on_fire',
                                     'distance_from_water_source',
                                     'first_bucket_drop_date',
                                     'bh_fs_date',
                                     'bh_hectares',
                                     'uc_fs_date',
                                     'uc_hectares',
                                     'to_fs_date',
                                     'to_hectares',
                                     'ex_fs_date',
                                     'ex_hectares',
                                       'dispatch_date',
                                       'start_for_fire_date',
                                       'assessment_datetime',
                                       'ia_arrival_at_fire_date',
                                       'fire_fighting_start_date'])

# https://stackoverflow.com/questions/13411544/delete-a-column-from-a-pandas-dataframe

# %%
wildfiredf.isna().sum()
# Out:
# fire_year                      0
# fire_number                    0
# fire_name                  24592
# current_size                   0
# size_class                     0
# fire_location_latitude         0
# fire_location_longitude        0
# fire_start_date              678
# discovered_date             4941
# reported_date                  0
# wind_direction              2823
# wind_speed                  2823
# dtype: int64

# %%
wildfiredf.fire_start_date.fillna(wildfiredf.discovered_date, inplace=True)
del wildfiredf['discovered_date']

# https://stackoverflow.com/questions/29177498/replace-nan-in-one-column-with-value-from-corresponding-row-of-second-column

# %%
wildfiredf.isna().sum()
# Out:
# fire_year                      0
# fire_number                    0
# fire_name                  24592
# current_size                   0
# size_class                     0
# fire_location_latitude         0
# fire_location_longitude        0
# fire_start_date              100
# reported_date                  0
# wind_direction              2823
# wind_speed                  2823
# dtype: int64

# %%
wildfiredf.fire_start_date.fillna(wildfiredf.reported_date, inplace=True)
del wildfiredf['reported_date']

# %%
wildfiredf.isna().sum()
# Out:
# fire_year                      0
# fire_number                    0
# fire_name                  24592
# current_size                   0
# size_class                     0
# fire_location_latitude         0
# fire_location_longitude        0
# fire_start_date                0
# wind_direction              2823
# wind_speed                  2823
# dtype: int64

# %%
wildfiredf.head()
# Out:
#    fire_year fire_number fire_name  current_size size_class  \
# 0       2006      PWF001       NaN          0.10          A
# 1       2006      EWF002       NaN          0.20          B
# 2       2006      EWF001       NaN          0.50          B
# 3       2006      EWF003       NaN          0.01          A
# 4       2006      PWF002       NaN          0.10          A
#
#    fire_location_latitude  fire_location_longitude      fire_start_date  \
# 0               56.249956              -117.181960  2006-04-02 12:00:00
# 1               53.606367              -115.915733  2006-04-03 12:10:00
# 2               53.610933              -115.594267  2006-04-03 12:15:00
# 3               53.608867              -115.609467  2006-04-03 12:10:00
# 4               56.249956              -117.050249  2006-04-03 17:00:00
#
#   wind_direction  wind_speed
# 0             SW         2.0
# 1             SW        10.0
# 2             SW        10.0
# 3             SW        10.0
# ...

# %%
wildfiredf = wildfiredf[wildfiredf['fire_year'] >= 2012]
wildfiredf = wildfiredf[wildfiredf['current_size'] >= 10]
wildfiredf.head()
# Out:
#       fire_year fire_number       fire_name  current_size size_class  \
# 9788       2012      HWF053             NaN          78.4          D
# 9798       2012      HWF070  Wolverine Fire        1689.0          E
# 9825       2012      HWF085   Jackpot Creek         748.0          E
# 9826       2012      HWF086             NaN          63.1          D
# 9827       2012      HWF087   Lessard River         198.5          D
#
#       fire_location_latitude  fire_location_longitude      fire_start_date  \
# 9788               58.515333              -116.452483  2012-05-09 14:55:00
# 9798               57.921350              -116.925533  2012-05-26 13:30:00
# 9825               59.766667              -117.088333  2012-05-30 18:00:00
# 9826               59.795333              -117.118667  2012-05-30 18:00:00
# 9827               59.868667              -116.779667  2012-05-30 14:00:00
#
#      wind_direction  wind_speed
# 9788              N        40.0
# 9798              S        25.0
# ...

# %%
wildfiredf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 916 entries, 9788 to 25311
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   fire_year                916 non-null    int64
#  1   fire_number              916 non-null    object
#  2   fire_name                246 non-null    object
#  3   current_size             916 non-null    float64
#  4   size_class               916 non-null    object
#  5   fire_location_latitude   916 non-null    float64
#  6   fire_location_longitude  916 non-null    float64
#  7   fire_start_date          916 non-null    object
#  8   wind_direction           910 non-null    object
#  9   wind_speed               910 non-null    float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 78.7+ KB

# %%
wildfiredf.to_csv('Alberta_wildfires_cleaned.csv')
